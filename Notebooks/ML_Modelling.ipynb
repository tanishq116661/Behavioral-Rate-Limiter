# %% [markdown]
# ### Creating ML Model for final Dataset

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
BASE_DATA_PATH = "../Dataset/final_data.parquet"

# %%
df = pd.read_parquet(BASE_DATA_PATH)
df.head()
# Out:
#    flow iat mean  flow iat std  flow duration  packet length std  \
# 0   1.309639e-04  4.457724e-04       0.003536           0.088965
# 1   8.483972e-04  2.152960e-03       0.002545           0.023615
# 2   8.666500e-04  0.000000e+00       0.000867           0.007931
# 3   5.277778e-07  8.139906e-07       0.000002           0.003241
# 4   7.474583e-04  1.896342e-03       0.002242           0.011692
#
#    avg packet size  total fwd packets  down/up ratio    iat_cv  prot_6  \
# 0         0.062402           0.000078        0.00000  0.040039    True
# 1         0.051627           0.000005        0.03125  0.029849   False
# 2         0.036815           0.000000        0.03125  0.000000   False
# 3         0.026627           0.000005        0.03125  0.018432   False
# 4         0.035274           0.000005        0.03125  0.029842   False
#
#    prot_17  label
# 0    False      0
# 1     True      0
# 2     True      0
# 3     True      0
# 4     True      0

# %%
X = df.drop(columns=["label"])
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['label']), df['label'], test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.score(X_test, y_test)
# Out:
# 0.8585

# %%
def create_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
def create_classification_report(model, X_test, y_test):
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred)
    print(report)
    return report

# %%
model_report = create_classification_report(model, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86     10035
#            1       0.88      0.83      0.85      9965
#
#     accuracy                           0.86     20000
#    macro avg       0.86      0.86      0.86     20000
# weighted avg       0.86      0.86      0.86     20000

# %%
create_confusion_matrix(model, X_test, y_test)

# %%
## Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_report = create_classification_report(dt_model, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     10035
#            1       0.99      0.99      0.99      9965
#
#     accuracy                           0.99     20000
#    macro avg       0.99      0.99      0.99     20000
# weighted avg       0.99      0.99      0.99     20000

# %%
create_confusion_matrix(dt_model, X_test, y_test)

# %%
## Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_report = create_classification_report(rf_model, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     10035
#            1       0.99      0.99      0.99      9965
#
#     accuracy                           0.99     20000
#    macro avg       0.99      0.99      0.99     20000
# weighted avg       0.99      0.99      0.99     20000

# %%
create_confusion_matrix(rf_model, X_test, y_test)

# %% [markdown]
# ##### Though Random Forest Classifier is performing best, but it is highly complex and may not be suitable for real-time predictions. Decision Tree Classifier is simpler and faster, making it a better choice for our use case. We will proceed with Decision Tree Classifier for our final model.

# %%
dt_model.get_depth()
# Out:
# 34

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

param_grid = {
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [10, 20, 50],
    'min_samples_leaf': [5, 10, 20],
    'criterion': ['gini', 'entropy']
}

# %%
grid_search = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

grid_search.fit(X_train, y_train)
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}

# %%
best_dt_model = grid_search.best_estimator_

# %%
best_dt_report = create_classification_report(best_dt_model, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     10035
#            1       0.99      0.99      0.99      9965
#
#     accuracy                           0.99     20000
#    macro avg       0.99      0.99      0.99     20000
# weighted avg       0.99      0.99      0.99     20000

# %%
create_confusion_matrix(best_dt_model, X_test, y_test)

# %%
feature_importances = best_dt_model.feature_importances_
feature_names = X_train.columns

# %%
fimp_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": feature_importances
}, ).sort_values(by="Importance", ascending=False)

# %%
sns.barplot(x="Importance", y="Feature", data=fimp_df.head(20))
plt.title("Top 20 Feature Importances from Decision Tree")
# Out:
# Text(0.5, 1.0, 'Top 20 Feature Importances from Decision Tree')

# %%
new_final_features = ["packet length std", "avg packet size", "total fwd packets"]

# %%
new_X_train = X_train[new_final_features]
new_X_test = X_test[new_final_features]

# %%
cv = GridSearchCV(estimator=DecisionTreeClassifier(random_state=42), param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
cv.fit(new_X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 15, 20],
#                          'min_samples_leaf': [5, 10, 20],
#                          'min_samples_split': [10, 20, 50]},
#              verbose=2)

# %%
new_best_dt_model = cv.best_estimator_

# %%
new_best_dt_model.score(new_X_test, y_test)
# Out:
# 0.9743

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,10))
plot_tree(new_best_dt_model, feature_names=new_final_features, filled=True, max_depth=3)
plt.title("Decision Tree Visualization (Top 3 Levels)")
# Out:
# Text(0.5, 1.0, 'Decision Tree Visualization (Top 3 Levels)')

# %%
create_classification_report(new_best_dt_model, new_X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     10035
#            1       0.99      0.96      0.97      9965
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
# '              precision    recall  f1-score   support\n\n           0       0.96      0.99      0.97     10035\n           1       0.99      0.96      0.97      9965\n\n    accuracy                           0.97     20000\n   macro avg       0.97      0.97      0.97     20000\nweighted avg       0.97      0.97      0.97     20000\n'

# %%
create_confusion_matrix(new_best_dt_model, new_X_test, y_test)

# %%
### Saaving best supervised model for future use
import pickle 
with open('../Models/best_new_dt_model.pkl', 'wb') as f:
    pickle.dump(new_best_dt_model, f)
